# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
g=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/abalone.csv")

# %%
g.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
g.drop(['Length','Diameter','Height'],axis=1,inplace=True)

# %%
g.head()
# Out:
#   Sex  Whole weight  Shucked weight  Viscera weight  Shell weight  Rings
# 0   M        0.5140          0.2245          0.1010         0.150     15
# 1   M        0.2255          0.0995          0.0485         0.070      7
# 2   F        0.6770          0.2565          0.1415         0.210      9
# 3   M        0.5160          0.2155          0.1140         0.155     10
# 4   I        0.2050          0.0895          0.0395         0.055      7

# %%
g.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Whole weight    4177 non-null   float64
#  2   Shucked weight  4177 non-null   float64
#  3   Viscera weight  4177 non-null   float64
#  4   Shell weight    4177 non-null   float64
#  5   Rings           4177 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 195.9+ KB

# %%
g.describe(include='all')
# Out:
#          Sex  Whole weight  Shucked weight  Viscera weight  Shell weight  \
# count   4177   4177.000000     4177.000000     4177.000000   4177.000000
# unique     3           NaN             NaN             NaN           NaN
# top        M           NaN             NaN             NaN           NaN
# freq    1528           NaN             NaN             NaN           NaN
# mean     NaN      0.828742        0.359367        0.180594      0.238831
# std      NaN      0.490389        0.221963        0.109614      0.139203
# min      NaN      0.002000        0.001000        0.000500      0.001500
# 25%      NaN      0.441500        0.186000        0.093500      0.130000
# 50%      NaN      0.799500        0.336000        0.171000      0.234000
# 75%      NaN      1.153000        0.502000        0.253000      0.329000
# max      NaN      2.825500        1.488000        0.760000      1.005000
#
#               Rings
# count   4177.000000
# unique          NaN
# top             NaN
# ...

# %%
g.isnull().sum()
# Out:
# Sex               0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# UNIVARIATE  ANALYSIS

# %%
sns.countplot(x='Sex', data=g)
plt.show()

# %%
cols=3
rows=3
num=g.select_dtypes(exclude='object').columns
fig=plt.figure(figsize=(cols*5,rows*5))
for i, col in enumerate(num):
  ax=fig.add_subplot(rows,cols,i+1)
  sns.histplot(x=g[col],ax=ax)

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
sns.kdeplot(data=g,x="Whole weight",y="Shucked weight")

# %%
sns.kdeplot(data=g,x="Shucked weight",y="Viscera weight")

# %%
sns.kdeplot(data=g,x="Viscera weight",y="Shell weight")

# %%
sns.lineplot(data=g,x="Whole weight",y="Shucked weight")

# %%
sns.lineplot(data=g,x="Shucked weight",y="Viscera weight")

# %%
sns.lineplot(data=g,x="Viscera weight",y="Shell weight")

# %%
sns.lineplot(data=g,x="Shell weight",y="Rings")

# %% [markdown]
# MULTIVARIATE ANALYSIS

# %%
sns.pairplot(g,'Rings')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# DESCRIPTIVE ANALYSIS

# %%
g.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Whole weight    4177 non-null   float64
#  2   Shucked weight  4177 non-null   float64
#  3   Viscera weight  4177 non-null   float64
#  4   Shell weight    4177 non-null   float64
#  5   Rings           4177 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 195.9+ KB

# %%
g.shape
# Out:
# (4177, 6)

# %%
g.describe().T
# Out:
#                  count      mean       std     min     25%     50%     75%  \
# Whole weight    4177.0  0.828742  0.490389  0.0020  0.4415  0.7995   1.153
# Shucked weight  4177.0  0.359367  0.221963  0.0010  0.1860  0.3360   0.502
# Viscera weight  4177.0  0.180594  0.109614  0.0005  0.0935  0.1710   0.253
# Shell weight    4177.0  0.238831  0.139203  0.0015  0.1300  0.2340   0.329
# Rings           4177.0  9.933684  3.224169  1.0000  8.0000  9.0000  11.000
#
#                     max
# Whole weight     2.8255
# Shucked weight   1.4880
# Viscera weight   0.7600
# Shell weight     1.0050
# Rings           29.0000

# %%
g.isna().any()
# Out:
# Sex               False
# Whole weight      False
# Shucked weight    False
# Viscera weight    False
# Shell weight      False
# Rings             False
# dtype: bool

# %%
sns.boxplot(g['Viscera weight'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# LABEL ENCODING

# %%
from sklearn.preprocessing import LabelEncoder
from collections import Counter as count

# %%
le = LabelEncoder()

# %%
g['Sex'].unique()
# Out:
# array(['M', 'F', 'I'], dtype=object)

# %%
g['Sex']=le.fit_transform(g['Sex'])

# %%
count(g['Sex'])
# Out:
# Counter({2: 1528, 0: 1307, 1: 1342})

# %% [markdown]
# SPLIT THE DATA INTO DEPENDENT AND INDEPENDENT VARIABLES

# %%
g.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   int64
#  1   Whole weight    4177 non-null   float64
#  2   Shucked weight  4177 non-null   float64
#  3   Viscera weight  4177 non-null   float64
#  4   Shell weight    4177 non-null   float64
#  5   Rings           4177 non-null   int64
# dtypes: float64(4), int64(2)
# memory usage: 195.9 KB

# %%
x=g.iloc[:,0:10]
y=g['Rings']

# %%
x
# Out:
#       Sex  Whole weight  Shucked weight  Viscera weight  Shell weight  Rings
# 0       2        0.5140          0.2245          0.1010        0.1500     15
# 1       2        0.2255          0.0995          0.0485        0.0700      7
# 2       0        0.6770          0.2565          0.1415        0.2100      9
# 3       2        0.5160          0.2155          0.1140        0.1550     10
# 4       1        0.2050          0.0895          0.0395        0.0550      7
# ...   ...           ...             ...             ...           ...    ...
# 4172    0        0.8870          0.3700          0.2390        0.2490     11
# 4173    2        0.9660          0.4390          0.2145        0.2605     10
# 4174    2        1.1760          0.5255          0.2875        0.3080      9
# 4175    0        1.0945          0.5310          0.2610        0.2960     10
# 4176    2        1.9485          0.9455          0.3765        0.4950     12
#
# [4177 rows x 6 columns]

# %%
y
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4177, dtype: int64

# %% [markdown]
# SPLIT DATA INTO TRAINING AND TESTING

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=10)

# %% [markdown]
# SCALE THE INDEPENDENT VARIABLE

# %%
from sklearn.preprocessing import StandardScaler

# %%
st = StandardScaler()

# %%
s_xtrain = st.fit_transform(xtrain)
s_xtrain
# Out:
# array([[-1.27405748, -0.28943253, -0.25422817, -0.14825699, -0.44753472,
#         -0.61411737],
#        [-1.27405748,  0.80934178,  0.70504918,  1.15508066,  0.75628097,
#          0.00755019],
#        [-1.27405748,  0.32735156,  0.18487766,  0.86595999,  0.38144016,
#          1.87255286],
#        ...,
#        [-1.27405748, -0.75304177, -0.75863691, -0.59341105, -0.83679249,
#         -0.92495115],
#        [ 1.1457411 ,  1.16368628,  1.96381923,  0.42539515,  0.38144016,
#          0.00755019],
#        [-0.06415819, -0.58863409, -0.52219531, -0.73108756, -0.51241101,
#         -0.61411737]])

# %%
s_xtest = st.transform(xtest)
s_xtest
# Out:
# array([[ 1.1457411 , -0.90315313, -0.74512596, -0.88253172, -0.99898323,
#         -0.92495115],
#        [ 1.1457411 ,  0.43865863,  0.5429178 ,  0.41621671,  0.38144016,
#          0.00755019],
#        [-1.27405748,  0.13333008,  0.18487766,  0.35655689, -0.06188119,
#         -0.61411737],
#        ...,
#        [ 1.1457411 ,  0.74092368,  0.90546159,  1.20097283,  0.37423168,
#          0.31838397],
#        [-0.06415819,  0.50911906,  0.02049446,  0.03990091,  0.95811834,
#          2.18338663],
#        [-1.27405748,  1.16981328,  1.15091049,  0.60437461,  1.83755256,
#          0.31838397]])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(10, activation='relu')) # Input
model.add(Dense(18, activation='relu')) # 1st hid. layer
model.add(Dense(9, activation='relu')) # 2nd hid. layer
model.add(Dense(8, activation='relu')) # 3rd hid. layer
model.add(Dense(1,activation='linear')) # output layer

# %%
model.compile(optimizer='adam',loss='mse',metrics=['mse'])

# %%
history= model.fit(s_xtrain,ytrain,batch_size=10,epochs=300)
# Out:
# Epoch 1/300
# 293/293 [==============================] - 1s 2ms/step - loss: 29.6319 - mse: 29.6319
# Epoch 2/300
# 293/293 [==============================] - 1s 2ms/step - loss: 0.6994 - mse: 0.6994
# Epoch 3/300
# 293/293 [==============================] - 1s 2ms/step - loss: 0.2558 - mse: 0.2558
# Epoch 4/300
# 293/293 [==============================] - 1s 2ms/step - loss: 0.1488 - mse: 0.1488
# Epoch 5/300
# 293/293 [==============================] - 1s 2ms/step - loss: 0.1046 - mse: 0.1046
# Epoch 6/300
# 293/293 [==============================] - 1s 2ms/step - loss: 0.0824 - mse: 0.0824
# Epoch 7/300
# 293/293 [==============================] - 1s 2ms/step - loss: 0.0668 - mse: 0.0668
# Epoch 8/300
# 293/293 [==============================] - 1s 2ms/step - loss: 0.0555 - mse: 0.0555
# Epoch 9/300
# 293/293 [==============================] - 1s 2ms/step - loss: 0.0463 - mse: 0.0463
# Epoch 10/300
# ...

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['mse'])
plt.title('Accuracy')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 10)                70
#
#  dense_1 (Dense)             (None, 18)                198
#
#  dense_2 (Dense)             (None, 9)                 171
#
#  dense_3 (Dense)             (None, 8)                 80
#
#  dense_4 (Dense)             (None, 1)                 9
#
# ...
# Total params: 528
# Trainable params: 528
# Non-trainable params: 0
# _________________________________________________________________
